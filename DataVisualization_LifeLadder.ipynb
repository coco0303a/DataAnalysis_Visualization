# %% [markdown]
# # 1.Python libraries for Data Science

# %% [markdown]
# *   Numpy https://numpy.org/doc/stable/
# *   pandas https://pandas.pydata.org/docs/
# *   matplotlib https://matplotlib.org/stable/gallery/index.html
# *   seaborn https://seaborn.pydata.org/examples/index.html

# %%
# importing pyhton Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2.Dataset

# %% [markdown]
# **Life Ladder dataset**
#  - The dataset can be obtained from [World Happiness Report](https://worldhappiness.report/ed/2022/#appendices-and-data)
#
# <table>
#   <tr>
#     <td><img src = "https://drive.google.com/uc?id=1-AlomJJupt8acw0Ul4KEQNU_f92x-Ffc" height = 300 width = 800></td>
#     <td><img src = "https://drive.google.com/uc?id=1GhoMCe_AOrhZVIZl_TPuMJWtEsnl5EX3" height = 300 width = 1000></td>
#   <tr>
# </table>

# %% [markdown]
# World Happiness Report use data from the Gallup World Poll surveys. They are based on answers to the main life evaluation question asked in the poll. It asks respondents to think of a ladder, with the best possible life for them being a 10 and the worst possible life being a 0.This is called the Cantril ladder.
#
# ▶ Analyze the Life Ladder data.
#
# ▶ What can we learn from Data analysis?
#
# *  Life Ladder Scores (Life Satisfaction) trend by year and countries
# *  Factors affecting life ladder scores
#
#
# ---

# %% [markdown]
# 1. loading dataset

# %%
file_path = "https://raw.githubusercontent.com/coco0303a/jupyter-notebooks/master/Life_Ladder.csv"
life = pd.read_csv(file_path)
life.head()
# Out:
#        Country  year  Life Ladder  GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590        7.302574        0.450662
# 1  Afghanistan  2009     4.401778        7.472446        0.552308
# 2  Afghanistan  2010     4.758381        7.579183        0.539075
# 3  Afghanistan  2011     3.831719        7.552006        0.521104
# 4  Afghanistan  2012     3.782938        7.637953        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.500000                      0.718114    0.173169
# 1                         50.799999                      0.678896    0.195469
# 2                         51.099998                      0.600127    0.125859
# 3                         51.400002                      0.495901    0.167723
# 4                         51.700001                      0.530935    0.241247
#
#    Perceptions of corruption
# 0                   0.881686
# 1                   0.850035
# ...

# %% [markdown]
# 2.Read data files from your Google Drive
#
#         - You can access files in Drive by mounting your Google Drive

# %%
## mount google drive 
#  from google.colab import drive
#  drive.mount('/content/drive')

# %%
## load data file
# life = pd.read_csv("/content/drive/MyDrive/data/Life_Ladder.csv")

# %% [markdown]
# # 3.Pandas Data Exploration Functions

# %%
# the first 5 rows
life.head()
# Out:
#        Country  year  Life Ladder  GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590        7.302574        0.450662
# 1  Afghanistan  2009     4.401778        7.472446        0.552308
# 2  Afghanistan  2010     4.758381        7.579183        0.539075
# 3  Afghanistan  2011     3.831719        7.552006        0.521104
# 4  Afghanistan  2012     3.782938        7.637953        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.500000                      0.718114    0.173169
# 1                         50.799999                      0.678896    0.195469
# 2                         51.099998                      0.600127    0.125859
# 3                         51.400002                      0.495901    0.167723
# 4                         51.700001                      0.530935    0.241247
#
#    Perceptions of corruption continent
# 0                   0.881686      Asia
# ...

# %%
# the last 5 rows
life.tail()
# Out:
#        Country  year  Life Ladder  GDP per capita  Social support  \
# 2084  Zimbabwe  2017     3.638300        8.241609        0.754147
# 2085  Zimbabwe  2018     3.616480        8.274620        0.775388
# 2086  Zimbabwe  2019     2.693523        8.196998        0.759162
# 2087  Zimbabwe  2020     3.159802        8.117733        0.717243
# 2088  Zimbabwe  2021     3.154578        8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 2084                         52.150002                      0.752826
# 2085                         52.625000                      0.762675
# 2086                         53.099998                      0.631908
# 2087                         53.575001                      0.643303
# 2088                         54.049999                      0.667636
#
#       Generosity  Perceptions of corruption continent
# 2084   -0.113937                   0.751208    Africa
# ...

# %%
# dimensionality of the DataFrame (number of rows and columns)
life.shape
# Out:
# (2089, 12)

# %%
# summary of a DataFrame
life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           2089 non-null   object
#  1   year                              2089 non-null   int64
#  2   Life Ladder                       2089 non-null   float64
#  3   GDP per capita                    2062 non-null   float64
#  4   Social support                    2076 non-null   float64
#  5   Healthy life expectancy at birth  2031 non-null   float64
#  6   Freedom to make life choices      2057 non-null   float64
#  7   Generosity                        2009 non-null   float64
#  8   Perceptions of corruption         1976 non-null   float64
#  9   continent                         2089 non-null   object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 163.3+ KB

# %%
# descriptive statistics
life.describe()
# Out:
#               year  Life Ladder  GDP per capita  Social support  \
# count  2089.000000  2089.000000     2062.000000     2076.000000
# mean   2013.727621     5.473747        9.378408        0.811542
# std       4.455614     1.115567        1.143520        0.118935
# min    2005.000000     2.178809        5.526723        0.290184
# 25%    2010.000000     4.651972        8.473547        0.747664
# 50%    2014.000000     5.405246        9.463269        0.834770
# 75%    2017.000000     6.294282       10.347656        0.904682
# max    2021.000000     8.018934       11.665803        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2031.000000                   2057.000000
# mean                          63.180326                      0.745462
# std                            6.948546                      0.140751
# min                            6.720000                      0.257534
# ...

# %% [markdown]
# # 4.Data Visualization

# %% [markdown]
# ## (Example 1) What are the Top 5 Asia countries with the highest life ladder score in 2021?

# %%
# install python pakage 
# !pip install country_converter

# importing country_converter library
import country_converter as coco

# add continent code 
life['continent']=coco.convert(names=list(life['Country']), to='continent')
life.head()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#        Country  year  Life Ladder  GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590        7.302574        0.450662
# 1  Afghanistan  2009     4.401778        7.472446        0.552308
# 2  Afghanistan  2010     4.758381        7.579183        0.539075
# 3  Afghanistan  2011     3.831719        7.552006        0.521104
# 4  Afghanistan  2012     3.782938        7.637953        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.500000                      0.718114    0.173169
# 1                         50.799999                      0.678896    0.195469
# 2                         51.099998                      0.600127    0.125859
# 3                         51.400002                      0.495901    0.167723
# 4                         51.700001                      0.530935    0.241247
#
# ...

# %%
# Create new dataframe
life5 = life.sort_values("Life Ladder", ascending=False).query('continent == "Asia" and year == 2021').head(5)

# Set font style
font_style = {
    'fontsize': 14,
    'fontweight': 'bold'      #  {‘normal’,‘bold’, 'heavy’,‘light’,‘ultrabold’,‘ultralight’} 
}

# Set size of figure
plt.figure(figsize=(15, 4))  

# Set titles for the figure 
plt.title('Top 5 countries in Asia', fontdict=font_style, loc='center', pad=15)  

# draw pointplot
sns.pointplot(data=life5, x="Country", y="Life Ladder", color='blue', ci=None) 

# naming the y axis
plt.ylabel("Life Ladder Score")
# Out:
# Text(0, 0.5, 'Life Ladder Score')

# %% [markdown]
# ## (Exercise 1) What are the Top 10 countries with the highest life ladder score in 2021?

# %%
life_top10 = life.sort_values("Life Ladder", ascending=False).query('year == 2021').head(10)

plt.figure(figsize=(15, 4))  
sns.pointplot(data=life_top10, x="Country", y="Life Ladder", color='blue', ci=None) 
plt.ylabel("Life Ladder Score")

# %%
life_top10 = life.sort_values("Life Ladder", ascending=False).query('year == 2021').head(10)

plt.________(figsize=(15, 4))  
sns.________(data=life_top10, x="Country", y="Life Ladder", color='blue', ci=None) 
plt.ylabel("Life Ladder Score")
# Out:
# Text(0, 0.5, 'Life Ladder Score')

# %% [markdown]
# ## (Exercise2) Create line plot that displays annual continent ladder score

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(data=life, x=life["year"], y=life["Life Ladder"], hue="continent", ci=None)   
plt.legend(bbox_to_anchor=(1, 1))

# %%
plt._______(figsize=(15, 5))
sns._______(data=life, x=life["year"], y=life["Life Ladder"], hue="continent", ci=None)   
plt._______(bbox_to_anchor=(1, 1))

# %% [markdown]
# ## (Exercise 3) Show the Life Ladder score by continent - bar plot

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=life,x="continent", y="Life Ladder" , errwidth=0)

# %%
plt._______(figsize=(10,4))
sns._______(data=life,x="continent", y="Life Ladder" , errwidth=0)

# %% [markdown]
# ## (Exercise 4) Show life ladder score by year in unitwin countries

# %% [markdown]
# ◼ Tips
# * relplot : If kind = "line", a line plot is drawn.
#   > relplot (kind: 'scatter'; default or 'line')
# * seaborn > Tutorial > Overview of seaborn plotting functions
#   > https://seaborn.pydata.org/tutorial/function_overview.html
# * seaborn > API > seaborn.relplot
#   > https://seaborn.pydata.org/generated/seaborn.relplot.html

# %%
life_unitwin= life[life['Country'].isin (['Cambodia','Indonesia','Laos','South Korea','Vietnam' ])]
sns.relplot(data=life_unitwin, x="year", y="Life Ladder", kind="line", hue="Country", col="Country", col_wrap=3)

# %%
life_unitwin= life[life['Country'].isin (['Cambodia','Indonesia','Laos','South Korea','Vietnam' ])]
sns.________(data=life_unitwin
            , x="year"
            , y="Life Ladder"
            , kind="________"
            , hue="_________"
            , col="Country"
            , col_wrap=3
            )

# %% [markdown]
# ## (Exercise 5) Is there correlation between Life Ladder score and Economy of the countries (GDP per capita)?

# %%
sns.scatterplot(data=life, x="Life Ladder" , y="GDP per capita", alpha=.9)

# %%
sns.________(data=life, x="Life Ladder" , y="GDP per capita", alpha=.9)

# %%
sns.scatterplot(data=life, x="Life Ladder" , y="GDP per capita", hue='continent', alpha=.9)

# %%
sns._________(data=life
              , x="Life Ladder" 
              , y="GDP per capita"
              , hue='_________'
              , alpha=.9)

# %%
sns.jointplot(x ="Life Ladder",  y ="GDP per capita", data=life, kind='reg')

# %%
sns.________(x ="Life Ladder",  y ="GDP per capita", data=life, kind='reg')

# %% [markdown]
# ## (Exercise 6) Show the relationship of Life Ladder score to other factors.

# %%
sns.pairplot(life[['Life Ladder'
              ,'GDP per capita'
              ,'Social support'
              ,'Healthy life expectancy at birth'
              ,'Freedom to make life choices'
              ,'Generosity', 'Perceptions of corruption']])

# %% [markdown]
# ## (Exercise 7) Show the correlation of factors - heatmap

# %%
data_corr =life[['Life Ladder', 'GDP per capita', 'Social support', 'Healthy life expectancy at birth',  'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']].corr()            
data_corr
# Out:
#                                   Life Ladder  GDP per capita  Social support  \
# Life Ladder                          1.000000        0.782158        0.713881
# GDP per capita                       0.782158        1.000000        0.681699
# Social support                       0.713881        0.681699        1.000000
# Healthy life expectancy at birth     0.713795        0.810385        0.597580
# Freedom to make life choices         0.531316        0.361541        0.409119
# Generosity                           0.187568       -0.000836        0.069759
# Perceptions of corruption           -0.429346       -0.343813       -0.222571
#
#                                   Healthy life expectancy at birth  \
# Life Ladder                                               0.713795
# GDP per capita                                            0.810385
# Social support                                            0.597580
# Healthy life expectancy at birth                          1.000000
# ...

# %%
sns.heatmap(data_corr, cmap="Blues", linewidths=2.0, linecolor='white', annot=True)

# %%
sns._________(_________, cmap="Blues", linewidths=2.0, linecolor='white', annot=True)

# %% [markdown]
# ## (Exercise 8) Show the distribution of life ladder score by continent

# %%
sns.displot(data=life, x='Life Ladder', col= 'continent', col_wrap=5)

# %%
sns.________(data=life, x='Life Ladder', col= '_________', col_wrap=5)

# %%
sns.kdeplot(data=life, x= 'Life Ladder', hue='continent')

# %%
sns.________(data=life, x= 'Life Ladder', hue='_________')
